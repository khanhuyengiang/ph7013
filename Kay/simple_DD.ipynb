# %%
import sys
from inverse_search import gates_set_generator, matrix_list, add_inverse_gates
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import numpy as np

# %%
gates_set = gates_set_generator(1)

# %%
from qutip_qip.compiler import GateCompiler, Instruction
from qutip_qip.device import ModelProcessor
from qutip import (sigmax, sigmay, sigmaz, tensor)

import functools # for reduce
from qutip.qip.operations.gates import *
from qutip import basis
from qutip_qip.circuit import QubitCircuit
from qutip.metrics import fidelity
from qutip.qip.noise import RandomNoise

# %%
from qutip_qip.operations import Gate

# %%
from qutip.solver import Options

# %%
aNaught = 25/46
# Decoherence time
T1 = 8.66e-6
T1_err = 0.49
T2 = 9.08e-6
T2_err = 0.74e-6
T2_echo =106.14e-6
T2_echo_err = 3.21e-6

# %%
_zz_operator = tensor([sigmaz(),sigmaz()])

# %%
class simple_processor(ModelProcessor):
    """
    Custom processor built using ModelProcessor as the base class.
    This custom processor will inherit all the methods of the base class
    such as setting up of the T1 and T2 decoherence rates in the simulations.

    Args:
        num_qubits (int): Number of qubits in the processor.
        t1, t2 (float or list): The T1 and T2 decoherence rates for the
    """

    def __init__(self, num_qubits, t1=None, t2=None):
        # call the parent class initializer
        super(simple_processor, self).__init__(num_qubits, t1=t1, t2=t2)  
        # The control pulse is discrete or continous.
        self.pulse_mode = "discrete"
        # The dimension of each controllable quantum system
        self.model.dims = [2] * num_qubits
        self.num_qubits = num_qubits
        self.set_up_ops()  # set up the available Hamiltonians
        self.native_gates = ["RX", "RY"]

    _zz_operator = tensor([sigmaz(),sigmaz()])

    def set_up_ops(self):
        """
        Sets up the control operators.
        """
        # sigmax pulse on m-th qubit with the corresponding pulse
        for m in range(self.num_qubits):
            self.add_control(1/2*sigmax(), m, label="sx" + str(m))
        # sy
        for m in range(self.num_qubits):
            self.add_control(1/2*sigmay(), m, label="sy" + str(m))
        # zz
        for m in range(self.num_qubits-1):
            self.add_control(_zz_operator, [m, m + 1], label="zz" + str(m))
        
    # To remove errors arise from RandomNoise not being recognized
    # as a type Noise, may cause trouble in the future?
    def add_noise(self, noise):
        """
        Add a noise object to the processor

        Parameters
        ----------
        noise: :class:`.Noise`
            The noise object defined outside the processor
        """
        self.noise.append(noise)

# %%
class simple_compiler(GateCompiler):
    """
    Custom compiler for generating pulses from gates using
    the base class GateCompiler.

    Args:
        num_qubits (int): The number of qubits in the processor
        params (dict): A dictionary of parameters for gate pulses
                       such as the pulse amplitude.
    """

    def __init__(self, num_qubits, params):
        super().__init__(num_qubits, params=params)
        self.params = params
        self.gate_compiler = {
            "RX": self.pulse_discretization_compiler,
            "RY": self.pulse_discretization_compiler,
        }

    def generate_pulse(self, gate, tlist, coeff, phase=0.0):
        """Generates the pulses.

        Args:
            gate (qutip_qip.circuit.Gate): A qutip Gate object.
            tlist (array): A list of times for the evolution.
            coeff (array): An array of coefficients for the gate pulses
            phase (float): The value of the phase for the gate.

        Returns:
            Instruction (qutip_qip.compiler.instruction.Instruction):
            An instruction to implement a gate containing the control pulses.
        """
        pulse_info = [
            # (control label, coeff)
            ("sx" + str(gate.targets[0]), np.cos(phase) * coeff),
            ("sy" + str(gate.targets[0]), np.sin(phase) * coeff),
            ("zz" + str(gate.targets[0]), 0.2 * coeff)
        ]
        return [Instruction(gate, tlist=tlist, pulse_info=pulse_info)]

    def pulse_discretization_compiler(self, gate, args):
        """Compiles single-qubit gates to pulses.

        Args:
            gate (qutip_qip.circuit.Gate): A qutip Gate object.

        Returns:
            Instruction (qutip_qip.compiler.instruction.Instruction):
            An instruction to implement a gate containing the control pulses.
        """
        # gate.arg_value is the rotation angle
        _step_list = np.linspace(0,1,11) # a time step list so that the noise work
        coupling_time_series = np.abs(gate.arg_value) / self.params["pulse_amplitude"] * _step_list
        s = aNaught - (1 - aNaught) * np.cos(2 * np.pi * _step_list[:-1])
        #FPGA_voltage = self.params["pulse_amplitude"] * np.sign(gate.arg_value) * s
        FPGA_voltage = self.params["pulse_amplitude"] * np.sign(gate.arg_value) * (_step_list[:-1]*0 + 1)
        if gate.name == "RX":
            return self.generate_pulse(gate, tlist = coupling_time_series, coeff = FPGA_voltage, phase=0.0)
        elif gate.name == "RY":
            return self.generate_pulse(gate, tlist = coupling_time_series, coeff = FPGA_voltage, phase=np.pi / 2)

# %%
num_qubits = 2
fidelity_list = []
index_list = []

for x in np.linspace(0.01,4,100):
    myprocessor = simple_processor(num_qubits)
    myprocessor.native_gates = None  # Remove the native gates
    mycompiler = simple_compiler(num_qubits,{"pulse_amplitude": 10})

    # Ground state for n qubits
    init_state = functools.reduce(lambda a, b: tensor(a,b), [basis(2, 0)] * num_qubits)

    # Define a random circuit.
    circuit = QubitCircuit(num_qubits)
    circuit.add_gate("RY", targets=0, arg_value=x*np.pi)
    

    # Simulate the circuit.
    myprocessor.load_circuit(circuit, compiler=mycompiler)
    
    # Compute results of the run using a solver of choice
    result = myprocessor.run_state(init_state, solver="mesolve")
    # Measured fidelity at the end
    final_fidelity = fidelity(result.states[0],result.states[-1])

    fidelity_list.append(final_fidelity)
    index_list.append(x)

plt.plot(index_list,fidelity_list)

# %%
from scipy.signal import argrelextrema
maximum_array = argrelextrema(np.asarray(fidelity_list), np.greater,order = 10)
first_max = maximum_array[0][0]
pulse_coeff = index_list[first_max]/2
print(pulse_coeff)
gates_set = gates_set_generator(pulse_coeff)
# Out:
# 0.931969696969697

# %%
num_qubits =1
fidelity_list = []
index_list = []
num_gates = 5

for x in np.linspace(0.01,4,100):
    myprocessor = simple_processor(num_qubits)
    myprocessor.native_gates = None  # Remove the native gates
    mycompiler = simple_compiler(num_qubits,{"pulse_amplitude": 1})

    # Ground state for n qubits
    init_state = functools.reduce(lambda a, b: tensor(a,b), [basis(2, 0)] * num_qubits)
   
    # Define a random circuit.
    circuit = QubitCircuit(num_qubits)
    clifford = rx(0)
    for ind in np.random.randint(0, 6, num_gates):
        circuit.add_gate(gates_set[ind])
        clifford = matrix_list[ind] * clifford

    init_state_1q = basis(2, 0)
    # Finding inverse Clifford for the random sequence of gate
    add_inverse_gates(clifford, init_state_1q, circuit = circuit)

    # Simulate the circuit.
    myprocessor.load_circuit(circuit, compiler=mycompiler)

    # Simulate the circuit.
    myprocessor.load_circuit(circuit, compiler=mycompiler)
    
    # Compute results of the run using a solver of choice
    result = myprocessor.run_state(init_state, solver="mesolve")
    # Measured fidelity at the end
    final_fidelity = fidelity(result.states[0],result.states[-1])

    fidelity_list.append(final_fidelity)
    index_list.append(x)

plt.plot(index_list,fidelity_list)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Code\ph7013_project_TanYuanzhengPaul\Kay\simple_DD.ipynb Cell 12 line 2
#      <a href='vscode-notebook-cell:/d%3A/Code/ph7013_project_TanYuanzhengPaul/Kay/simple_DD.ipynb#X15sZmlsZQ%3D%3D?line=22'>23</a> add_inverse_gates(clifford, init_state_1q, circuit = circuit)
#      <a href='vscode-notebook-cell:/d%3A/Code/ph7013_project_TanYuanzhengPaul/Kay/simple_DD.ipynb#X15sZmlsZQ%3D%3D?line=24'>25</a> # Simulate the circuit.
# ---> <a href='vscode-notebook-cell:/d%3A/Code/ph7013_project_TanYuanzhengPaul/Kay/simple_DD.ipynb#X15sZmlsZQ%3D%3D?line=25'>26</a> myprocessor.load_circuit(circuit, compiler=mycompiler)
#      <a href='vscode-notebook-cell:/d%3A/Code/ph7013_project_TanYuanzhengPaul/Kay/simple_DD.ipynb#X15sZmlsZQ%3D%3D?line=27'>28</a> # Simulate the circuit.
#      <a href='vscode-notebook-cell:/d%3A/Code/ph7013_project_TanYuanzhengPaul/Kay/simple_DD.ipynb#X15sZmlsZQ%3D%3D?line=28'>29</a> myprocessor.load_circuit(circuit, compiler=mycompiler)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qutip_qip\device\modelprocessor.py:242, in ModelProcessor.load_circuit(self, qc, schedule_mode, compiler)
#     240     raise ValueError("No compiler defined.")
#     241 # Save compiler pulses
# --> 242 self.set_coeffs(coeffs)
#     243 self.set_tlist(tlist)
#     244 return tlist, coeffs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qutip_qip\device\processor.py:441, in Processor.set_coeffs(self, coeffs)
#     439 for label, coeff in iterator:
#     440     label = label
# --> 441     ham, targets = self.model.get_control(label)
#     442     self.add_pulse(
#     443         Pulse(
#     444             ham,
#    (...)
#     449         )
#     450     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\qutip_qip\device\processor.py:1345, in Model.get_control(self, label)
#    1343     if isinstance(label, int):
#    1344         label = _old_index_label_map[label]
# -> 1345 return self._controls[label]
#
# KeyError: 'zz0'

# %%
def single_simple_simulation(num_gates, t1 = None, t2 = None, num_qubits = 2, 
                             add_FPGA_noise = True, add_DD = True):
    """
    A single simulation, with num_gates representing the number of rotations.

    Args:
        num_gates (int): The number of random gates to add in the simulation.
        t1, t2 (float): Decoherence time of the qubits.
        add_FPGA_noise (bool): Whether to add in gaussian FPGA noise to the simulation.

    Returns:
        final_fidelity (float):
            Fidelity of the result state (obtained from 
            mesolve solver method) and the initial state.
    """
     
    myprocessor = simple_processor(num_qubits, t1 = t1, t2 = t2)
    myprocessor.native_gates = None  # Remove the native gates
    mycompiler = simple_compiler(num_qubits,{"pulse_amplitude": 10})

    # Ground state for n qubits
    init_state = functools.reduce(lambda a, b: tensor(a,b), [basis(2, 0)] * num_qubits)

    # Define a random circuit.
    circuit = QubitCircuit(num_qubits)
    clifford = rx(0)

    if add_DD == True:
        for ind in np.random.randint(0, 6, num_gates):
            circuit.add_gate(gates_set[ind])
            for i in range(10):
                circuit.add_gate("RX", targets=0, arg_value=0.1*2*np.pi)
            clifford = matrix_list[ind] * clifford
    else:
        for ind in np.random.randint(0, 6, num_gates):
            circuit.add_gate(gates_set[ind])
            clifford = matrix_list[ind] * clifford

    init_state_1q = basis(2, 0)
    # Finding inverse Clifford for the random sequence of gate
    add_inverse_gates(clifford, init_state_1q, circuit = circuit)

    # Simulate the circuit.
    myprocessor.load_circuit(circuit, compiler=mycompiler)
    
    # FPGA gaussian noise
    if add_FPGA_noise == True:
        FPGA_noise = RandomNoise(dt=0.001, indices = [0,1], rand_gen=np.random.normal, loc=0.00, scale=0.3)
        myprocessor.add_noise(FPGA_noise)
    
    # Compute results of the run using a solver of choice
    result = myprocessor.run_state(init_state, solver="mesolve")
    # Measured fidelity at the end
    final_fidelity = fidelity(result.states[0],result.states[-1])
    return final_fidelity

# %%
def simulation_test_run(num_gates_list, num_sample, 
                        add_FPGA_noise = False, add_DD =True,
                         t1 = None, t2 = None):
    fidelity_average = []
    fidelity_error = []
    for num_gates in num_gates_list:
        fidelity_list = [single_simple_simulation(
            num_gates, t1 = t1, t2 = t2,
            add_FPGA_noise = add_FPGA_noise, add_DD = add_DD,
            ) for i in range(num_sample)]
        fidelity_average.append(np.mean(fidelity_list))
        fidelity_error.append(np.std(fidelity_list) / np.sqrt(num_sample))
    
    return fidelity_average, fidelity_error

# %%
def run_and_add_to_dictionary(fidelity_and_error_dictionary, 
                                   num_gates_list, num_sample, 
                                   add_FPGA_noise = False, add_DD = True,
                                   t1 = None, t2 = None):
    fidelity_and_error = simulation_test_run(
        num_gates_list, num_sample, add_DD = add_DD,
        add_FPGA_noise = add_FPGA_noise, t1 = t1, t2 = t2)

    if add_DD == False:
        add_DD_str = 'No DD '
    else:
        add_DD_str = "DD "

    if add_FPGA_noise == False:
        if t1 == None and t2 == None:
            FPGA_decoherence_str = 'baseline'
        else:
            FPGA_decoherence_str = 'with decoherence'
    else:
        if t1 == None and t2 == None:
            FPGA_decoherence_str = 'with FPGA noise'
        else:
            FPGA_decoherence_str = 'with FPGA noise and decoherence'

    label_for_plt = add_DD_str + FPGA_decoherence_str
    fidelity_and_error_dictionary[label_for_plt] = fidelity_and_error

# %%
num_sample = 5
#num_gates_list = np.linspace(1,300,25,dtype=int)
num_gates_list = np.arange(5,105,20)

# %%
T1 =10
T2 = 10

# %%
fidelity_and_error_dictionary = {}
for add_DD in [True, False]:
    for add_FPGA_noise in [True, False]:
        run_and_add_to_dictionary(fidelity_and_error_dictionary, 
                                   num_gates_list, num_sample, 
                                   add_FPGA_noise = add_FPGA_noise, add_DD = add_DD,
                                   t1 = None, t2 = None)
        run_and_add_to_dictionary(fidelity_and_error_dictionary, 
                                   num_gates_list, num_sample, 
                                   add_FPGA_noise = add_FPGA_noise, add_DD = add_DD,
                                   t1 = T1, t2 = T2)
        print(1)
sorted_fidelity_and_error_dictionary = {i: fidelity_and_error_dictionary[i] for i in sorted(fidelity_and_error_dictionary)}
# Out:
# 1
# 1
# 1
# 1

# %%
colors = cm.rainbow(np.linspace(0, 1, 8))
plt.autoscale(enable=True, axis="y", tight=False)
i = 0
for label_key in sorted_fidelity_and_error_dictionary:
    plt.errorbar(num_gates_list, sorted_fidelity_and_error_dictionary[label_key][0], 
                 yerr=sorted_fidelity_and_error_dictionary[label_key][1], 
                capsize=5, label = label_key, color=colors[i])
    i = i+1

plt.xlabel("Number of Gates")
plt.ylabel("Ground State Fidelity")

# Force plt legend order (it's undetermined in the source code)
plt.legend()

# %% [markdown]
# fidelity_baseline, error_baseline = simulation_test_run(
#     num_gates_list, num_sample, add_DD = False,
#     add_FPGA_noise = False, t1 = None, t2 = None)
# fidelity_t1t2, error_t1t2 = simulation_test_run(
#     num_gates_list, num_sample, add_DD = False,
#     add_FPGA_noise = False, t1 = T1, t2 = T2)
# fidelity_FPGA, error_FPGA = simulation_test_run(
#     num_gates_list, num_sample, add_DD = False,
#     add_FPGA_noise = True, t1 = None, t2 = None)
# fidelity_FPGA_t1t2, error_FPGA_t1t2 = simulation_test_run(
#     num_gates_list, num_sample, add_DD = False,
#     add_FPGA_noise = True, t1 = T1, t2 = T2)

# %% [markdown]
# plt.autoscale(enable=True, axis="y", tight=False)
# plt.errorbar(num_gates_list, fidelity_baseline, yerr=error_baseline,
#              color='red', capsize=5,label = 'Baseline')
# plt.errorbar(num_gates_list, fidelity_FPGA, yerr=error_FPGA,
#              color='magenta', capsize=5, label = 'With FPGA noise')
# plt.errorbar(num_gates_list, fidelity_t1t2, yerr=error_t1t2,
#              color='blue', capsize=5, label = 'With decoherence')
# plt.errorbar(num_gates_list, fidelity_FPGA_t1t2, yerr=error_FPGA_t1t2,
#              color='green', capsize=5, label = 'With FPGA noise and decoherence')
# plt.legend()
# plt.xlabel("Number of Gates")
# plt.ylabel("Ground State Fidelity")
